# %%
#importing data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('Premier_League_Results.csv')
df.head()
# Out:
#        Date  Round Venue Result  Goals_For  Goals_Against        Opponent  \
# 0  01/01/24     20  Home      W          4              2       Newcastle
# 1  12/26/23     19  Away      W          2              0         Burnley
# 2  12/23/23     18  Home      D          1              1         Arsenal
# 3  12/17/23     17  Home      D          0              0  Manchester Utd
# 4  09/12/23     16  Away      W          2              1  Crystal Palace
#
#     XGF   XGA       Team Unnamed: 10
# 0  7.20  0.67  Liverpool         NaN
# 1  1.75  0.72  Liverpool         NaN
# 2  1.01  0.87  Liverpool         NaN
# 3  2.66  0.52  Liverpool
# 4  1.26  1.99  Liverpool         NaN

# %%
#converting date to correct format for reading in ml algorithm

df["Date"] = pd.to_datetime(df["Date"])
# Out:
# C:\Users\ab185568\AppData\Local\Temp\ipykernel_14060\1345762788.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Date             datetime64[ns]
# Round                     int64
# Venue                    object
# Result                   object
# Goals_For                 int64
# Goals_Against             int64
# Opponent                 object
# XGF                     float64
# XGA                     float64
# Team                     object
# Unnamed: 10              object
# dtype: object

# %%
#converting appropriate variables for ml algorithm to correctly read and predict

df["Venue_Code"] = df["Venue"].astype("category").cat.codes

# %%
df["Opp_Code"] = df["Opponent"].astype("category").cat.codes

# %%
df["Target"] = (df["Result"] == "W").astype("int")

# %%
df
# Out:
#           Date  Round Venue Result  Goals_For  Goals_Against        Opponent  \
# 0   2024-01-01     20  Home      W          4              2       Newcastle
# 1   2023-12-26     19  Away      W          2              0         Burnley
# 2   2023-12-23     18  Home      D          1              1         Arsenal
# 3   2023-12-17     17  Home      D          0              0  Manchester Utd
# 4   2023-09-12     16  Away      W          2              1  Crystal Palace
# ..         ...    ...   ...    ...        ...            ...             ...
# 711 2023-03-15     27  Home      L          0              2       Brentford
# 712 2023-03-12     26  Away      D          0              0  Manchester Utd
# 713 2023-03-04     25  Home      W          1              0       Leicester
# 714 2023-02-25     24  Away      L          0              1           Leeds
# 715 2023-02-18     23  Away      W          1              0         Chelsea
#
#       XGF   XGA         Team Unnamed: 10  Venue_Code  Opp_Code  Target
# 0    7.20  0.67    Liverpool         NaN           1        16       1
# 1    1.75  0.72    Liverpool         NaN           0         5       1
# 2    1.01  0.87    Liverpool         NaN           1         0       0
# 3    2.66  0.52    Liverpool                       1        15       0
# 4    1.26  1.99    Liverpool         NaN           0         7       1
# ..    ...   ...          ...         ...         ...       ...     ...
# 711  0.55  2.15  Southampton         NaN           1         3       0
# 712  1.25  0.92  Southampton         NaN           0        15       0
# 713  1.52  2.09  Southampton         NaN           1        11       1
# 714  0.39  0.94  Southampton         NaN           0        10       0
# 715  0.90  1.67  Southampton         NaN           0         6       1
#
# [716 rows x 14 columns]

# %%
df['Venue']=df['Venue'].astype('category').cat.codes

# %%
#strange column added into dataset which is now removed

df = df.drop('Unnamed: 10', axis = 1)

# %%
df.dropna()
# Out:
#           Date  Round  Venue Result  Goals_For  Goals_Against        Opponent  \
# 0   2024-01-01     20      1      W          4              2       Newcastle
# 1   2023-12-26     19      0      W          2              0         Burnley
# 2   2023-12-23     18      1      D          1              1         Arsenal
# 3   2023-12-17     17      1      D          0              0  Manchester Utd
# 4   2023-09-12     16      0      W          2              1  Crystal Palace
# ..         ...    ...    ...    ...        ...            ...             ...
# 711 2023-03-15     27      1      L          0              2       Brentford
# 712 2023-03-12     26      0      D          0              0  Manchester Utd
# 713 2023-03-04     25      1      W          1              0       Leicester
# 714 2023-02-25     24      0      L          0              1           Leeds
# 715 2023-02-18     23      0      W          1              0         Chelsea
#
#       XGF   XGA         Team  Venue_Code  Opp_Code  Target
# 0    7.20  0.67    Liverpool           1        16       1
# 1    1.75  0.72    Liverpool           0         5       1
# 2    1.01  0.87    Liverpool           1         0       0
# 3    2.66  0.52    Liverpool           1        15       0
# 4    1.26  1.99    Liverpool           0         7       1
# ..    ...   ...          ...         ...       ...     ...
# 711  0.55  2.15  Southampton           1         3       0
# 712  1.25  0.92  Southampton           0        15       0
# 713  1.52  2.09  Southampton           1        11       1
# 714  0.39  0.94  Southampton           0        10       0
# 715  0.90  1.67  Southampton           0         6       1
#
# [716 rows x 13 columns]

# %%
#importing random forest model

from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
#setting up train and test, data is from Feb 2023

train = df[df["Date"] < '2023-10-29']

# %%
test = df[df["Date"] > '2023-10-29']

# %%
#These two variables used as the predictors for the model, can add more predictors

predictors = ["Venue_Code", "Opp_Code","XGF","XGA"]

# %%
rf.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
#testing accuracy of model

from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["Target"], preds)

# %%
acc
# Out:
# 0.6538461538461539

# %%
combined = pd.DataFrame(dict(actual=test["Target"], prediction=preds))

# %%
#comparing how many times we predicted a result and how many times we were right against how many times we were wrong

pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           60  15
# 1           30  25

# %%
#importing precision score

from sklearn.metrics import precision_score

# %%
precision_score(test["Target"], preds)
# Out:
# 0.625

# %%
grouped_df = df.groupby("Team")

# %%
#running a rolling average to help improve model accuracy

def rolling_average(group, cols, new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["Goals_For", "Goals_Against"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['Goals_For_rolling', 'Goals_Against_rolling']

# %%
df_rolling = df.groupby("Team").apply(lambda x: rolling_average(x, cols, new_cols))

# %%
df_rolling
# Out:
#                   Date  Round  Venue Result  Goals_For  Goals_Against  \
# Team
# Arsenal 425 2023-02-25     25      0      W          1              0
#         424 2023-03-04     26      1      W          3              2
#         75  2023-03-09      4      1      W          3              1
#         423 2023-03-12     27      0      W          0              3
#         422 2023-03-19     28      1      W          4              1
# ...                ...    ...    ...    ...        ...            ...
# Wolves  206 2023-11-27     13      0      L          2              3
#         202 2023-12-17     17      0      L          0              3
#         201 2023-12-24     18      1      W          2              1
#         200 2023-12-27     19      0      W          4              1
#         199 2023-12-30     20      1      W          3              0
#
#                    Opponent   XGF   XGA     Team  Venue_Code  Opp_Code  \
# Team
# Arsenal 425       Leicester  0.69  0.02  Arsenal           0        11
#         424     Bournemouth  2.77  1.45  Arsenal           1         2
#         75   Manchester Utd  1.41  0.94  Arsenal           1        15
#         423          Fulham  2.52  0.84  Arsenal           0         9
#         422  Crystal Palace  1.57  0.64  Arsenal           1         7
# ...                     ...   ...   ...      ...         ...       ...
# Wolves  206          Fulham  1.46  2.97   Wolves           0         9
#         202        West Ham  0.61  0.99   Wolves           0        21
#         201         Chelsea  1.39  1.94   Wolves           1         6
#         200       Brentford  1.80  2.32   Wolves           0         3
#         199         Everton  2.23  0.52   Wolves           1         8
#
#              Target  Goals_For_rolling  Goals_Against_rolling
# Team
# Arsenal 425       1           2.333333               1.333333
#         424       1           2.333333               1.000000
#         75        1           2.666667               1.333333
#         423       1           2.333333               1.000000
#         422       1           2.000000               2.000000
# ...             ...                ...                    ...
# Wolves  206       0           2.000000               1.333333
#         202       0           2.000000               2.000000
#         201       1           1.333333               2.333333
#         200       1           1.333333               2.333333
#         199       1           2.000000               1.666667
#
# [647 rows x 15 columns]

# %%
df_rolling.index = range(df_rolling.shape[0])

# %%
df_rolling
# Out:
#           Date  Round  Venue Result  Goals_For  Goals_Against        Opponent  \
# 0   2023-02-25     25      0      W          1              0       Leicester
# 1   2023-03-04     26      1      W          3              2     Bournemouth
# 2   2023-03-09      4      1      W          3              1  Manchester Utd
# 3   2023-03-12     27      0      W          0              3          Fulham
# 4   2023-03-19     28      1      W          4              1  Crystal Palace
# ..         ...    ...    ...    ...        ...            ...             ...
# 642 2023-11-27     13      0      L          2              3          Fulham
# 643 2023-12-17     17      0      L          0              3        West Ham
# 644 2023-12-24     18      1      W          2              1         Chelsea
# 645 2023-12-27     19      0      W          4              1       Brentford
# 646 2023-12-30     20      1      W          3              0         Everton
#
#       XGF   XGA     Team  Venue_Code  Opp_Code  Target  Goals_For_rolling  \
# 0    0.69  0.02  Arsenal           0        11       1           2.333333
# 1    2.77  1.45  Arsenal           1         2       1           2.333333
# 2    1.41  0.94  Arsenal           1        15       1           2.666667
# 3    2.52  0.84  Arsenal           0         9       1           2.333333
# 4    1.57  0.64  Arsenal           1         7       1           2.000000
# ..    ...   ...      ...         ...       ...     ...                ...
# 642  1.46  2.97   Wolves           0         9       0           2.000000
# 643  0.61  0.99   Wolves           0        21       0           2.000000
# 644  1.39  1.94   Wolves           1         6       1           1.333333
# 645  1.80  2.32   Wolves           0         3       1           1.333333
# 646  2.23  0.52   Wolves           1         8       1           2.000000
#
#      Goals_Against_rolling
# 0                 1.333333
# 1                 1.000000
# 2                 1.333333
# 3                 1.000000
# 4                 2.000000
# ..                     ...
# 642               1.333333
# 643               2.000000
# 644               2.333333
# 645               2.333333
# 646               1.666667
#
# [647 rows x 15 columns]

# %%
#making predictions based off new combined preds

def make_predictions(data, predictors):
    train = data[data["Date"] < '2023-11-25']
    test = data[data["Date"] > '2023-11-25']
    rf.fit(train[predictors], train["Target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(atual=test["Target"], predicted=preds), index=test.index)
    precision = precision_score(test["Target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(df_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.7096774193548387

# %%
combined
# Out:
#      atual  predicted
# 28       1          1
# 29       1          1
# 30       0          0
# 31       0          1
# 32       0          0
# ..     ...        ...
# 642      0          0
# 643      0          0
# 644      1          0
# 645      1          0
# 646      1          1
#
# [104 rows x 2 columns]

# %%
combined = combined.merge(df_rolling[["Date", "Team", "Result", "Opponent"]], left_index=True, right_index=True)

# %%
combined
# Out:
#      atual  predicted       Date     Team Result           Opponent
# 28       1          1 2023-12-08  Arsenal      W  Nottingham Forest
# 29       1          1 2023-12-17  Arsenal      W           Brighton
# 30       0          0 2023-12-23  Arsenal      D          Liverpool
# 31       0          1 2023-12-28  Arsenal      L           West Ham
# 32       0          0 2023-12-31  Arsenal      L             Fulham
# ..     ...        ...        ...      ...    ...                ...
# 642      0          0 2023-11-27   Wolves      L             Fulham
# 643      0          0 2023-12-17   Wolves      L           West Ham
# 644      1          0 2023-12-24   Wolves      W            Chelsea
# 645      1          0 2023-12-27   Wolves      W          Brentford
# 646      1          1 2023-12-30   Wolves      W            Everton
#
# [104 rows x 6 columns]

# %%
acc
# Out:
# 0.6538461538461539

# %%
combined["new_team"] = combined["Team"]

# %%
merged = combined.merge(combined, left_on=["Date", "new_team"], right_on=["Date", "Opponent"])

# %%
merged
# Out:
#      atual_x  predicted_x       Date   Team_x Result_x         Opponent_x  \
# 0          1            1 2023-12-08  Arsenal        W  Nottingham Forest
# 1          1            1 2023-12-17  Arsenal        W           Brighton
# 2          0            0 2023-12-23  Arsenal        D          Liverpool
# 3          0            1 2023-12-28  Arsenal        L           West Ham
# 4          0            0 2023-12-31  Arsenal        L             Fulham
# ..       ...          ...        ...      ...      ...                ...
# 99         0            0 2023-11-27   Wolves        L             Fulham
# 100        0            0 2023-12-17   Wolves        L           West Ham
# 101        1            0 2023-12-24   Wolves        W            Chelsea
# 102        1            0 2023-12-27   Wolves        W          Brentford
# 103        1            1 2023-12-30   Wolves        W            Everton
#
#     new_team_x  atual_y  predicted_y             Team_y Result_y Opponent_y  \
# 0      Arsenal        0            0  Nottingham Forest        L    Arsenal
# 1      Arsenal        0            0           Brighton        L    Arsenal
# 2      Arsenal        0            0          Liverpool        D    Arsenal
# 3      Arsenal        1            0           West Ham        W    Arsenal
# 4      Arsenal        1            0             Fulham        W    Arsenal
# ..         ...      ...          ...                ...      ...        ...
# 99      Wolves        1            1             Fulham        W     Wolves
# 100     Wolves        1            1           West Ham        W     Wolves
# 101     Wolves        0            0            Chelsea        L     Wolves
# 102     Wolves        0            0          Brentford        L     Wolves
# 103     Wolves        0            0            Everton        L     Wolves
#
#             new_team_y
# 0    Nottingham Forest
# 1             Brighton
# 2            Liverpool
# 3             West Ham
# 4               Fulham
# ..                 ...
# 99              Fulham
# 100           West Ham
# 101            Chelsea
# 102          Brentford
# 103            Everton
#
# [104 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)] ["atual_x"].value_counts()
# Out:
# atual_x
# 1    22
# 0     9
# Name: count, dtype: int64

# %%
9 / 22
# Out:
# 0.4090909090909091

# %%
acc
# Out:
# 0.6538461538461539

# %%
precision_score(test["Target"], preds)
# Out:
# 0.625
